# %%
# %matplotlib widget

from base import ClickableMol
from rdkit import Chem

# %% [markdown]
# # Display the molecule

# %%
mol = Chem.MolFromSmiles('CCN(CC)C(=O)[C@H]1CN([C@@H]2Cc3c[nH]c4c3c(ccc4)C2=C1)C')

display = ClickableMol()
_, clicked = display.plot(mol, tolerance=25, width=300, height=300, figsize=(5,4))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Click a few atoms and `clicked` will be updated in realtime

# %%
clicked
# Out:
# {14, 21, 22}
